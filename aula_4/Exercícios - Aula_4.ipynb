# %% [markdown]
# # <font color='blue'>Curso de Extensão - Análise de Dados em Python - Visualização Gráfica- Exercícios</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.express as px

# %% [markdown]
# #### 1) Carregue o dataset bank-data.csv" em um dataframe e gere os gráficos solicitados abaixo.

# %% [markdown]
# #### 2) Utilize a biblioteca Matplotlib para gerar um histograma da idade dos clientes do banco.

# %% [markdown]
# #### 3) Utilize a biblioteca Matplotlib para gerar um histograma da renda salarial (income) dos clientes do banco.

# %% [markdown]
# #### 4) Utilize a biblioteca Matplotlib para gerar um scatter plot (gráfico de dispersão) entre idade e valor salarial dos clientes do banco.

# %% [markdown]
# #### 5) Utilize a biblioteca Matplotlib para gerar um gráfico de linha mostrando a renda salarial nas diferentes regiões .

# %% [markdown]
# #### 6) Utilize a biblioteca Seaborn para gerar o boxplot  da renda salarial das pessoas que possuem e não possuem conta poupança (save_act).

# %% [markdown]
# #### 7) Utilize a biblioteca Seaborn para gerar o boxplot  da renda salarial por região para os clientes que possuem e não possuem aplicação (pep) .

# %% [markdown]
# #### 9) Utilize a biblioteca Plotly para gerar um histograma por renda salarial (income), identificando se o cliente é casado ou não (married).

# %% [markdown]
# #### 10) Utilize a biblioteca Plotly para gerar um histograma por renda salarial (income), identificando se o cliente possui ou não aplicação (pep).

# %% [markdown]
# #### 11) Utilize a biblioteca Plotly para gerar o boxplot da renda salarial por região e por cliente que possui ou não hipotéca (mortgage).

# %% [markdown]
# #### 12) Utilize a biblioteca Plotly para gerar o boxplot da renda salarial por filhos e por cliente que possui ou não carro (car).

# %% [markdown]
# #### 13) Utilize a biblioteca Plotly para gerar um gráfico de dispersão (scatter plot) entre a renda salarial e a idade, identificando o sexco do cliente.

# %% [markdown]
# #### 14) Procure nas bibliotecas Matplotlib, Seaborn e Plotly pelo menos mais dois modelos de gráficos diferentes dos gerados acima para a visualizações dos dados.
